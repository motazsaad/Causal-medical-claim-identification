# %% [markdown]
# <a href="https://colab.research.google.com/github/motazsaad/Causal-medical-claim-identification/blob/main/PIOFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/st1_train_inc_text.csv", encoding="ISO-8859-1")
text = [_ for _ in df.loc[lambda d: d["text"].str.lower().str.contains("adhd")]["text"]]

# %%
'''
python -m spacy download en_core_web_sm
'''
# Out:
# '\npython -m spacy download en_core_web_sm\n'

# %%
import spacy

# %%
from spacy import displacy
doc =  nlp(text[0])
displacy.render(doc, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8875c3eb24c743fd8f280f734a24fdcc-0" class="displacy" width="55700" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">prescribed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
# ...

# %%
for t in doc:
  print(t, t.pos_ , t.dep_)
# Out:
# De PROPN compound
# - PUNCT punct
# Nial PROPN nsubj
#
#  SPACE dep
# I PRON nsubj
# wrote VERB ROOT
# this PRON dobj
# a DET det
# few ADJ amod
# years NOUN npadvmod
# ago ADV advmod
# and CCONJ cc
# just ADV advmod
# found VERB conj
# it PRON dobj
# again ADV advmod
# . PUNCT punct
#   SPACE dep
# I PRON nsubj
# thought VERB ccomp
# I PRON nsubj
# 'd AUX aux
# share VERB ccomp
# ... PUNCT punct
#
#
#  SPACE dep
# & CCONJ cc
# # SYM nmod
# x200B NOUN conj
# ; PUNCT punct
#
#
#  SPACE dep
# When SCONJ advmod
# I PRON nsubj
# was AUX advcl
# 17 NUM attr
# , PUNCT punct
# it PRON nsubj
# was AUX ROOT
# a DET det
# very ADV advmod
# good ADJ amod
# year NOUN attr
# . PUNCT punct
# Like ADP prep
# the DET det
# opening NOUN compound
# line NOUN pobj
# of ADP prep
# the DET det
# old ADJ amod
# Frank PROPN compound
# Sanatra PROPN compound
# song NOUN pobj
# , PUNCT punct
# when SCONJ advmod
# I PRON nsubj
# was AUX advcl
# 17 NUM attr
# , PUNCT punct
# it PRON nsubj
# truly ADV advmod
# ...

# %%
def has_adhd(text):
  doc = nlp(text)
  for t in doc :
    if t.pos_ != 'VERB':
      return True
  return False   

g = (title for title in text if has_adhd(title))   
[next(g) for i in  range(5)]
# Out:
# ["Been prescribed Vyvanse for suspected ADHD and i'm kinda scared to take it because of the psychotic episode i had years ago.\nI'm failing at life right now, but the worst thing for me feels like it would have to be having people know. I still feel like i have lingering schizo-type symptoms, but i went to the psych for the ADHD and he leaned towards adhd. I feel like because i'm so non-communicative about my psychotic episode and nobody that matters noticed when it happened, and i somehow still functioned even though i was mentally wrecked, that they think idk i lied and i don't have it. So i've been prescribed Vyvanse and was told obviously that if i develop psychotic symptoms to report it and get that looked at immediately. Idk, i guess maybe i feel like i've done such a good job pretending it never happened, and the Vyvanse might blow up my life like a stick of dynamite. Even though i know i still have some very very minor positive but explain away with logic symptoms, but a lot 
# ...
